nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  \
# 5291                       246        1       302                     265
#
#       ...  Diabetes Mellitus  Chronic Kidney Disease  Poisonings  \
# 5291  ...               1365                    2270         114
#
#       Protein-Energy Malnutrition  Road Injuries  \
# 5291                          211           2157
#
#       Chronic Respiratory Diseases  \
# 5291                          2442
#
#       Cirrhosis and Other Chronic Liver Diseases  Digestive Diseases  \
# 5291                                        1439                1961
#
#       Fire, Heat, and Hot Substances  Acute Hepatitis
# 5291                             282               77
#
# ...

# %%
# checking datatype of dataframe
df.dtypes
# Out:
# Country/Territory                             object
# Code                                          object
# Year                                           int64
# Meningitis                                     int64
# Alzheimer's Disease and Other Dementias        int64
# Parkinson's Disease                            int64
# Nutritional Deficiencies                       int64
# Malaria                                        int64
# Drowning                                       int64
# Interpersonal Violence                         int64
# Maternal Disorders                             int64
# HIV/AIDS                                       int64
# Drug Use Disorders                             int64
# Tuberculosis                                   int64
# Cardiovascular Diseases                        int64
# Lower Respiratory Infections                   int64
# Neonatal Disorders                             int64
# Alcohol Use Disorders                          int64
# ...

# %%
#checking information of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country/Territory                           6120 non-null   object
#  1   Code                                        6120 non-null   object
#  2   Year                                        6120 non-null   int64
#  3   Meningitis                                  6120 non-null   int64
#  4   Alzheimer's Disease and Other Dementias     6120 non-null   int64
#  5   Parkinson's Disease                         6120 non-null   int64
#  6   Nutritional Deficiencies                    6120 non-null   int64
#  7   Malaria                                     6120 non-null   int64
#  8   Drowning                                    6120 non-null   int64
#  9   Interpersonal Violence                      6120 non-null   int64
# ...

# %%
#checking for null values
df.isnull().sum()
# Out:
# Country/Territory                             0
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# ...

# %%
#visualization of null values
plt.figure(figsize=(20,18))
plt.title('visualization of null values')
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# we don't have any null value in dataset

# %%
# Creating a function which will remove extra leading
# and tailing whitespace from the data.
# pass dataframe as a parameter here
def whitespace_remover(df):
   # iterating over the columns
    for i in df.columns:
         # checking datatype of each columns
        if df[i].dtype == 'object':
              # applying strip function on column
            df[i] = df[i].map(str.strip)
        else:
              # if condn. is False then it will do nothing.
            pass
 
# applying whitespace_remover function on dataframe
whitespace_remover(df)
 
# printing dataframe
df
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...

# %%
# unique value in column year
df['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
plt.figure(figsize=(30,25))
plt.subplot(2,2,1)
df.groupby("Year").sum()["Meningitis"].plot(marker="o")
plt.ylabel("Death by Meningitis")
plt.title("Death by Meningitis vs year")
plt.subplot(2,2,2)
df.groupby("Year").sum()["Alzheimer's Disease and Other Dementias"].plot(marker="o")
plt.ylabel("Death by Alzheimer's Disease and Other Dementias")
plt.title("Death by Alzheimer's Disease and Other Dementias vs year")
plt.subplot(2,2,3)
df.groupby("Year").sum()["Parkinson's Disease"].plot(marker="o")
plt.ylabel("Death by Parkinson's Disease")
plt.title("Death by Parkinson's Disease vs year")
plt.subplot(2,2,4)
df.groupby("Year").sum()["Nutritional Deficiencies"].plot(marker="o")
plt.ylabel("Death by Nutritional Deficiencies")
plt.title("Death by Nutritional Deficiencies vs year")
# Out:
# Text(0.5, 1.0, 'Death by Nutritional Deficiencies vs year')

# %% [markdown]
# observation:
#
#     1. Except for 1996, when the death rate climbed over the year before, meningitis-related deaths are declining. in 1990 more than 42500 death were recorded which is high death record.
#
#     2. Death by Alzheimer's Disease and Other Dementias death rates are rising year over year.
#
#     3. Parkinson's disease death rates are rising year over year. more than 350000 deaths were recorded in 2019 which is high death record.
#
#     4. Deaths caused by nutritional deficiencies are on the decline, although overall death rates are rising slowly in 1995. and in 1990 high record in death recorded which is more than 700000.

# %%
plt.figure(figsize=(30,25))
plt.subplot(2,2,1)
df.groupby("Year").sum()["Malaria"].plot(marker="o")
plt.ylabel("Death by Malaria")
plt.title("Death by Malaria vs year")
plt.subplot(2,2,2)
df.groupby("Year").sum()["Drowning"].plot(marker="o")
plt.ylabel("Drowning")
plt.title("Death by Drowning vs year")
plt.subplot(2,2,3)
df.groupby("Year").sum()["Interpersonal Violence"].plot(marker="o")
plt.ylabel("Death by Interpersonal Violence")
plt.title("Death by Interpersonal Violence vs year")
plt.subplot(2,2,4)
df.groupby("Year").sum()["Maternal Disorders"].plot(marker="o")
plt.ylabel("Death by Maternal Disorders")
plt.title("Death by Maternal Disorders vs year")
# Out:
# Text(0.5, 1.0, 'Death by Maternal Disorders vs year')

# %% [markdown]
# observation:
#
#     1. in year 2003 and 2004 deaths by malaria is increased,which is reported by highest deaths of malaria after that deaths are gradually decreased but from 2017 death rate is increasing
#     2. death by drowing is decreases by year over year and highest death recorded in 1990
#     3. Death by Interpersonal Violence is high in 2003
#     4. Death by Maternal Disorders is decreases by year over year highest death recorded in 1990.

# %%
plt.figure(figsize=(30,25))
plt.subplot(3,2,1)
df.groupby("Year").sum()["HIV/AIDS"].plot(marker="o")
plt.ylabel("Death by HIV/AIDS")
plt.title("Death by HIV/AIDS vs year")
plt.subplot(3,2,2)
df.groupby("Year").sum()["Drug Use Disorders"].plot(marker="o")
plt.ylabel("Drug Use Disorders")
plt.title("Death by Drug Use Disorders vs year")
plt.subplot(3,2,3)
df.groupby("Year").sum()["Tuberculosis"].plot(marker="o")
plt.ylabel("Death by Tuberculosis")
plt.title("Death by Tuberculosis vs year")
plt.subplot(3,2,4)
df.groupby("Year").sum()["Cardiovascular Diseases"].plot(marker="o")
plt.ylabel("Death by Cardiovascular Diseases")
plt.title("Death by Cardiovascular Diseases vs year")
plt.subplot(3,2,5)
df.groupby("Year").sum()["Lower Respiratory Infections"].plot(marker="o")
plt.ylabel("Death by Lower Respiratory Infections")
plt.title("Death by Lower Respiratory Infections vs year")
plt.subplot(3,2,6)
df.groupby("Year").sum()["Neonatal Disorders"].plot(marker="o")
plt.ylabel("Death by Neonatal Disorders")
plt.title("Death by Neonatal Disorders vs year")
# Out:
# Text(0.5, 1.0, 'Death by Neonatal Disorders vs year')

# %% [markdown]
# observation:
#
#     1. Death by HIV/AIDS is increases from 1990 year over year, but we observed that deaths are decreases from 2004 which recorded as highest death year.
#     2. we observed that Death by Drug Use Disorders is increased upto 2000 then fall in record observed upto 2005 and then again high increase record observed and highest death record in 2019.
#     3. Death by Tuberculosis decrease year over year and highest death record in 1992 .
#     4. Death by Cardiovascular Diseases increases year over year and highest death record in 2019.
#     5. Death by Lower Respiratory Infections decrease year over year and highest death record in 1990.
#     6. Death by Neonatal Disorders decrease year over year and highest death record in 2019.

# %%
plt.figure(figsize=(30,25))
plt.subplot(3,2,1)
df.groupby("Year").sum()["Alcohol Use Disorders"].plot(marker="o")
plt.ylabel("Death by Alcohol Use Disorders")
plt.title("Death by Alcohol Use Disorders vs year")
plt.subplot(3,2,2)
df.groupby("Year").sum()["Self-harm"].plot(marker="o")
plt.ylabel("Self-harm")
plt.title("Death by Self-harm vs year")
plt.subplot(3,2,3)
df.groupby("Year").sum()["Exposure to Forces of Nature"].plot(marker="o")
plt.ylabel("Death by Exposure to Forces of Nature")
plt.title("Death by Exposure to Forces of Nature vs year")
plt.subplot(3,2,4)
df.groupby("Year").sum()["Diarrheal Diseases"].plot(marker="o")
plt.ylabel("Death by Diarrheal Diseases")
plt.title("Death by Diarrheal Diseases vs year")
plt.subplot(3,2,5)
df.groupby("Year").sum()["Environmental Heat and Cold Exposure"].plot(marker="o")
plt.ylabel("Death by Environmental Heat and Cold Exposure")
plt.title("Death by Environmental Heat and Cold Exposure vs year")
plt.subplot(3,2,6)
df.groupby("Year").sum()["Neoplasms"].plot(marker="o")
plt.ylabel("Death by Neoplasms")
plt.title("Death by Neoplasms vs year")
# Out:
# Text(0.5, 1.0, 'Death by Neoplasms vs year')

# %% [markdown]
# Observation:
#
#     1. Death by Alcohol Use Disorders increases from 1990 and scores high in 2005 but after 2005 there is decrease in death rate
#     2. Death by Self-harm is highly unstable and recorded high in 1999
#     3. Death by Exposure to Forces of Nature is highly unstable and recorded high in 2004, 2008 and 2010
#     4. Death by Diarrheal Diseases decreses gradually and recorded high in 1991
#     5. Death by Environmental Heat and Cold Exposure is unstable and recorded high in 1995
#     6. Death by Neoplasms increases year over year and recorded high in 2019

# %%
plt.figure(figsize=(30,25))
plt.subplot(3,2,1)
df.groupby("Year").sum()["Conflict and Terrorism"].plot(marker="o")
plt.ylabel("Death by Conflict and Terrorism")
plt.title("Death by Conflict and Terrorism vs year")
plt.subplot(3,2,2)
df.groupby("Year").sum()["Diabetes Mellitus"].plot(marker="o")
plt.ylabel("Diabetes Mellitus")
plt.title("Death by Diabetes Mellitus vs year")
plt.subplot(3,2,3)
df.groupby("Year").sum()["Chronic Kidney Disease"].plot(marker="o")
plt.ylabel("Death by Chronic Kidney Disease")
plt.title("Death by Chronic Kidney Disease vs year")
plt.subplot(3,2,4)
df.groupby("Year").sum()["Poisonings"].plot(marker="o")
plt.ylabel("Death by Poisonings")
plt.title("Death by Poisonings vs year")
plt.subplot(3,2,5)
df.groupby("Year").sum()["Protein-Energy Malnutrition"].plot(marker="o")
plt.ylabel("Death by Protein-Energy Malnutrition")
plt.title("Death by Protein-Energy Malnutrition vs year")
plt.subplot(3,2,6)
df.groupby("Year").sum()["Road Injuries"].plot(marker="o")
plt.ylabel("Death by Road Injuries")
plt.title("Death by Road Injuries vs year")
# Out:
# Text(0.5, 1.0, 'Death by Road Injuries vs year')

# %% [markdown]
# Observation:
#
#     1. Death by Conflict and Terrorism is highly unstable and recorded very high rate in 1994
#     2. Death by Diabetes Mellitus is increases year over year and recorded high in 2019
#     3. Death by Chronic Kidney Disease is increases year over year and recorded high in 2019
#     4. Death by Poisonings is unstable and recorded high in 2005
#     5. Death by Protein-Energy Malnutrition is decreases and recorded high in 1990
#     6. Death by Road Injuries increases year over year upto 2008 which recorded as high rate after that it decreases gradually

# %%
plt.figure(figsize=(30,25))
plt.subplot(3,2,1)
df.groupby("Year").sum()["Chronic Respiratory Diseases"].plot(marker="o")
plt.ylabel("Death by Chronic Respiratory Diseases")
plt.title("Death by Chronic Respiratory Diseases vs year")
plt.subplot(3,2,2)
df.groupby("Year").sum()["Cirrhosis and Other Chronic Liver Diseases"].plot(marker="o")
plt.ylabel("Cirrhosis and Other Chronic Liver Diseases")
plt.title("Death by Cirrhosis and Other Chronic Liver Diseases")
plt.subplot(3,2,3)
df.groupby("Year").sum()["Digestive Diseases"].plot(marker="o")
plt.ylabel("Death by Digestive Diseases")
plt.title("Death by Digestive Diseases vs year")
plt.subplot(3,2,4)
df.groupby("Year").sum()["Fire, Heat, and Hot Substances"].plot(marker="o")
plt.ylabel("Death by Fire, Heat, and Hot Substances")
plt.title("Death by Fire, Heat, and Hot Substances vs year")
plt.subplot(3,2,5)
df.groupby("Year").sum()["Acute Hepatitis"].plot(marker="o")
plt.ylabel("Death by Acute Hepatitis")
plt.title("Death by Acute Hepatitis vs year")
# Out:
# Text(0.5, 1.0, 'Death by Acute Hepatitis vs year')

# %% [markdown]
# Observation:
# 1. Death by Chronic Respiratory Diseases increases year over year and recorded high in 2019
# 2. Death by Cirrhosis and Other Chronic Liver Diseases increases year over year and recorded high in 2019
# 3. Death by Digestive Diseases increases year over year and recorded high in 2019
# 4. Death by Fire, Heat, and Hot Substances is highly unstable and recorded high in 1994
# 5. Death by Acute Hepatitis decreses year over year and recorded high in 1990.

# %%
#checking number of unique value in dataframe
df.nunique()
# Out:
# Country/Territory                              204
# Code                                           204
# Year                                            30
# Meningitis                                    2020
# Alzheimer's Disease and Other Dementias       3037
# Parkinson's Disease                           1817
# Nutritional Deficiencies                      2147
# Malaria                                       1723
# Drowning                                      1875
# Interpersonal Violence                        2142
# Maternal Disorders                            1818
# HIV/AIDS                                      2412
# Drug Use Disorders                             876
# Tuberculosis                                  2843
# Cardiovascular Diseases                       5225
# Lower Respiratory Infections                  4106
# Neonatal Disorders                            3553
# Alcohol Use Disorders                         1287
# ...

# %%
for i in df.columns:
    c=df[i].value_counts()
    print('value count of',i,'is',c)
# Out:
# value count of Country/Territory is Afghanistan         30
# Papua New Guinea    30
# Niue                30
# North Korea         30
# North Macedonia     30
#                     ..
# Greenland           30
# Grenada             30
# Guam                30
# Guatemala           30
# Zimbabwe            30
# Name: Country/Territory, Length: 204, dtype: int64
# value count of Code is AFG    30
# PNG    30
# NIU    30
# PRK    30
# MKD    30
#        ..
# GRL    30
# GRD    30
# GUM    30
# GTM    30
# ZWE    30
# Name: Code, Length: 204, dtype: int64
# value count of Year is 1990    204
# 1991    204
# 2018    204
# 2017    204
# 2016    204
# 2015    204
# 2014    204
# 2013    204
# 2012    204
# 2011    204
# 2010    204
# 2009    204
# 2008    204
# 2007    204
# 2006    204
# 2005    204
# 2004    204
# 2003    204
# 2002    204
# 2001    204
# 2000    204
# 1999    204
# 1998    204
# 1997    204
# 1996    204
# 1995    204
# 1994    204
# 1993    204
# 1992    204
# ...

# %%
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
country_terrorism = df.groupby("Country/Territory").sum()["Conflict and Terrorism"].sort_values(ascending=False)
sns.barplot(x=country_terrorism[1:21].values,y=country_terrorism[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2019 due to Conflict and Terrorism")
plt.subplot(3,2,2)
country_Meningitis = df.groupby("Country/Territory").sum()["Meningitis"].sort_values(ascending=False)
sns.barplot(x=country_Meningitis[1:21].values,y=country_Meningitis[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Meningitis")
plt.subplot(3,2,3)
country_Alzheimer = df.groupby("Country/Territory").sum()["Alzheimer's Disease and Other Dementias"].sort_values(ascending=False)
sns.barplot(x=country_Alzheimer[1:21].values,y=country_Alzheimer[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Alzheimer's Disease and Other Dementias")
plt.subplot(3,2,4)
country_Parkinson = df.groupby("Country/Territory").sum()["Parkinson's Disease"].sort_values(ascending=False)
sns.barplot(x=country_Parkinson[1:21].values,y=country_Parkinson[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Parkinson's Disease")
plt.subplot(3,2,5)
country_Deficiencies = df.groupby("Country/Territory").sum()["Nutritional Deficiencies"].sort_values(ascending=False)
sns.barplot(x=country_Deficiencies[1:21].values,y=country_Deficiencies[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Nutritional Deficiencies")
plt.subplot(3,2,6)
country_Malaria = df.groupby("Country/Territory").sum()["Malaria"].sort_values(ascending=False)
sns.barplot(x=country_Malaria[1:21].values,y=country_Malaria[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Malaria")
plt.show()

# %% [markdown]
# Observation:
#
#     1. Total Death due to Conflict and Terrorism is high in Syria followed by Iraq
#     2. Total Death due to Meningitis is high in Nigeria followed by Pakistan
#     3. Total Death due to Alzheimer's Disease and Other Dementias is high in United State followed by Japan
#     4. Total Death due to Parkinson's Disease is high in India followed by United State
#     5. Total Death due to Nutritional Deficiencies is high in Ethopia followed by Bangladesh
#     6. Total Death due to Malaria is high in Republic of congo followed by India

# %%
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
country_Drowning = df.groupby("Country/Territory").sum()["Drowning"].sort_values(ascending=False)
sns.barplot(x=country_Drowning[1:21].values,y=country_Drowning[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2019 due to Drowning")
plt.subplot(3,2,2)
country_Violence = df.groupby("Country/Territory").sum()["Interpersonal Violence"].sort_values(ascending=False)
sns.barplot(x=country_Violence[1:21].values,y=country_Violence[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Interpersonal Violence")
plt.subplot(3,2,3)
country_Maternal = df.groupby("Country/Territory").sum()["Maternal Disorders"].sort_values(ascending=False)
sns.barplot(x=country_Maternal[1:21].values,y=country_Maternal[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Maternal Disorders")
plt.subplot(3,2,4)
country_HIV = df.groupby("Country/Territory").sum()["HIV/AIDS"].sort_values(ascending=False)
sns.barplot(x=country_HIV[1:21].values,y=country_HIV[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to HIV/AIDS")
plt.subplot(3,2,5)
country_Drug = df.groupby("Country/Territory").sum()["Drug Use Disorders"].sort_values(ascending=False)
sns.barplot(x=country_Drug[1:21].values,y=country_Drug[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Drug Use Disorders")
plt.subplot(3,2,6)
country_Tuberculosis = df.groupby("Country/Territory").sum()["Tuberculosis"].sort_values(ascending=False)
sns.barplot(x=country_Tuberculosis[1:21].values,y=country_Tuberculosis[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Tuberculosis")
plt.show()

# %% [markdown]
# Observation:
#
#     1. Total Death due to Drowning is high in India followed by Bangladesh
#     2. Total Death due to Interpersonal Violence is high in India followed by Russia
#     3. Total Death due to Maternal Disorders is high in Nigeria followed by Pakistan
#     4. Total Death due to HIV/AIDS is high in Kenya followed by Tanzaia and India
#     5. Total Death due to Drug Use Disorders is high in China followed by Russia
#     6. Total Death due to Tuberculosis is high in Indonesia followed by China

# %%
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
country_Cardiovascular = df.groupby("Country/Territory").sum()["Cardiovascular Diseases"].sort_values(ascending=False)
sns.barplot(x=country_Cardiovascular[1:21].values,y=country_Cardiovascular[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2019 due to Cardiovascular Diseases")
plt.subplot(3,2,2)
country_Respiratory = df.groupby("Country/Territory").sum()["Lower Respiratory Infections"].sort_values(ascending=False)
sns.barplot(x=country_Respiratory[1:21].values,y=country_Respiratory[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Lower Respiratory Infections")
plt.subplot(3,2,3)
country_Neonatal = df.groupby("Country/Territory").sum()["Neonatal Disorders"].sort_values(ascending=False)
sns.barplot(x=country_Neonatal[1:21].values,y=country_Neonatal[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Neonatal Disorders")
plt.subplot(3,2,4)
country_Alcohol = df.groupby("Country/Territory").sum()["Alcohol Use Disorders"].sort_values(ascending=False)
sns.barplot(x=country_Alcohol[1:21].values,y=country_Alcohol[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Alcohol Use Disorders")
plt.subplot(3,2,5)
country_Self = df.groupby("Country/Territory").sum()["Self-harm"].sort_values(ascending=False)
sns.barplot(x=country_Self[1:21].values,y=country_Self[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Self-harm")
plt.subplot(3,2,6)
country_Nature = df.groupby("Country/Territory").sum()["Exposure to Forces of Nature"].sort_values(ascending=False)
sns.barplot(x=country_Nature[1:21].values,y=country_Nature[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Exposure to Forces of Nature")
plt.show()

# %% [markdown]
# Observation:
#
#     1. Total Death due to Cardiovascular Diseases is high in India followed by Russia
#     2. Total Death due to Lower Respiratory Infections is high in China followed by Nigeria
#     3. Total Death due to Neonatal Disorders is high in Pakistan followed by Nigeria
#     4. Total Death due to Alcohol Use Disorders is high in India followed by China, United State
#     5. Total Death due to Self-harm is high in China followed by Russia
#     6. Total Death due to Exposure to Forces of Nature is high in Indonesia followed by Bangladesh

# %%
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
country_Diarrheal = df.groupby("Country/Territory").sum()["Diarrheal Diseases"].sort_values(ascending=False)
sns.barplot(x=country_Diarrheal[1:21].values,y=country_Diarrheal[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2019 due to Diarrheal Diseases")
plt.subplot(3,2,2)
country_Environment = df.groupby("Country/Territory").sum()["Environmental Heat and Cold Exposure"].sort_values(ascending=False)
sns.barplot(x=country_Environment[1:21].values,y=country_Environment[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Environmental Heat and Cold Exposure")
plt.subplot(3,2,3)
country_Neoplasms = df.groupby("Country/Territory").sum()["Neoplasms"].sort_values(ascending=False)
sns.barplot(x=country_Neoplasms[1:21].values,y=country_Neoplasms[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Neoplasms")
plt.subplot(3,2,4)
country_Diabetes = df.groupby("Country/Territory").sum()["Diabetes Mellitus"].sort_values(ascending=False)
sns.barplot(x=country_Diabetes[1:21].values,y=country_Diabetes[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Diabetes Mellitus")
plt.subplot(3,2,5)
country_Kidney = df.groupby("Country/Territory").sum()["Chronic Kidney Disease"].sort_values(ascending=False)
sns.barplot(x=country_Kidney[1:21].values,y=country_Kidney[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Chronic Kidney Disease")
plt.subplot(3,2,6)
country_Poisonings = df.groupby("Country/Territory").sum()["Poisonings"].sort_values(ascending=False)
sns.barplot(x=country_Poisonings[1:21].values,y=country_Poisonings[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Poisonings")
plt.show()

# %% [markdown]
# Observation:
#
#     1. Total Death due to Diarrheal Diseases is high in Nigeria followed by Pakistan
#     2. Total Death due to Environmental Heat and Cold Exposure is high in India followed by China
#     3. Total Death due to Neoplasms is high in United State followed by Japan
#     4. Total Death due to Diabetes Mellitus is high in China followed by United State
#     5. Total Death due to Chronic Kidney Disease is high in China followed by United State
#     6. Total Death due to Poisonings is high in Russia followed by India

# %%
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
country_Protein = df.groupby("Country/Territory").sum()["Protein-Energy Malnutrition"].sort_values(ascending=False)
sns.barplot(x=country_Protein[1:21].values,y=country_Protein[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2019 due to Protein-Energy Malnutrition")
plt.subplot(3,2,2)
country_Road = df.groupby("Country/Territory").sum()["Road Injuries"].sort_values(ascending=False)
sns.barplot(x=country_Road[1:21].values,y=country_Road[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Road Injuries")
plt.subplot(3,2,3)
country_Respiratory = df.groupby("Country/Territory").sum()["Chronic Respiratory Diseases"].sort_values(ascending=False)
sns.barplot(x=country_Respiratory[1:21].values,y=country_Respiratory[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Chronic Respiratory Diseases")
plt.subplot(3,2,4)
country_Live = df.groupby("Country/Territory").sum()["Cirrhosis and Other Chronic Liver Diseases"].sort_values(ascending=False)
sns.barplot(x=country_Live[1:21].values,y=country_Live[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Cirrhosis and Other Chronic Liver Diseases")
plt.subplot(3,2,5)
country_Digestive = df.groupby("Country/Territory").sum()["Digestive Diseases"].sort_values(ascending=False)
sns.barplot(x=country_Digestive[1:21].values,y=country_Digestive[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Digestive Diseases")
plt.subplot(3,2,6)
country_Fire = df.groupby("Country/Territory").sum()["Fire, Heat, and Hot Substances"].sort_values(ascending=False)
sns.barplot(x=country_Fire[1:21].values,y=country_Fire[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-2017 due to Fire, Heat, and Hot Substances")
plt.show()

# %% [markdown]
# Observation:
#
#     1. Total Death due to Protein-Energy Malnutrition is high in Ethopia followed by North korea
#     2. Total Death due to Road Injuries is high in India followed by United State
#     3. Total Death due to Chronic Respiratory Diseases is high in India followed by United State
#     4. Total Death due to Cirrhosis and Other Chronic Liver Diseases is high in China followed by Indonesia
#     5. Total Death due to Digestive Diseases is high in China followed by Indonesia
#     6. Total Death due to Fire, Heat, and Hot Substances is high in China followed by Russia

# %%
country_terrorism = df.groupby("Country/Territory").sum()["Acute Hepatitis"].sort_values(ascending=False)
sns.barplot(x=country_terrorism[1:21].values,y=country_terrorism[1:21].index,orient="h")
plt.xlabel("Total Deaths 1990-